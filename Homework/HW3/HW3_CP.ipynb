# %%
import csv
import datetime as dt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('student_logins.csv')

# %%
data.head()
# Out:
#   session_start_time session_end_time class_id  problems_completed  \
# 0       1/6/12 16:28     1/6/12 16:55        e                  37
# 1       1/7/12 11:00     1/7/12 11:27        e                  24
# 2        1/8/12 9:04      1/8/12 9:31        e                  50
# 3       1/9/12 12:41     1/9/12 12:48        e                  26
# 4       1/9/12 16:59     1/9/12 17:43        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91           10/26/11 0:00                             76
# 1         161             1/6/12 0:00                              2
# 2         141           12/31/11 0:00                              8
# 3         101           11/16/11 0:00                            199
# 4         103           11/23/11 0:00                            100
#
#    student_previous_class_logins
# 0                             27
# 1                              0
# 2                              5
# 3                            104
# 4                             41

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48758 entries, 0 to 48757
# Data columns (total 8 columns):
# session_start_time               48758 non-null object
# session_end_time                 48758 non-null object
# class_id                         48758 non-null object
# problems_completed               48758 non-null int64
# student_id                       48758 non-null int64
# student_account_created          48758 non-null object
# student_previous_logins_total    48758 non-null int64
# student_previous_class_logins    48758 non-null int64
# dtypes: int64(4), object(4)

# %%
data.session_start_time = pd.to_datetime(data.session_start_time)

# %%
data.session_end_time = pd.to_datetime(data.session_end_time)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48758 entries, 0 to 48757
# Data columns (total 8 columns):
# session_start_time               48758 non-null datetime64[ns]
# session_end_time                 48758 non-null datetime64[ns]
# class_id                         48758 non-null object
# problems_completed               48758 non-null int64
# student_id                       48758 non-null int64
# student_account_created          48758 non-null object
# student_previous_logins_total    48758 non-null int64
# student_previous_class_logins    48758 non-null int64
# dtypes: datetime64[ns](2), int64(4), object(2)

# %%
np.timedelta64(1, 's')
# Out:
# numpy.timedelta64(1,'s')

# %%
data['duration'] = (data.session_end_time - data.session_start_time) / np.timedelta64(1, 's')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 14 columns):
# session_start_time               5 non-null datetime64[ns]
# session_end_time                 5 non-null datetime64[ns]
# class_id                         5 non-null object
# problems_completed               5 non-null int64
# student_id                       5 non-null int64
# student_account_created          5 non-null object
# student_previous_logins_total    5 non-null int64
# student_previous_class_logins    5 non-null int64
# duration                         5 non-null float64
# a                                5 non-null float64
# c                                5 non-null float64
# e                                5 non-null float64
# g                                5 non-null float64
# m                                5 non-null float64
# dtypes: datetime64[ns](2), float64(6), int64(4), object(2)

# %%
data.head()
# Out:
#    session_start_time    session_end_time class_id  problems_completed  \
# 0 2012-01-06 16:28:00 2012-01-06 16:55:00        e                  37
# 1 2012-01-07 11:00:00 2012-01-07 11:27:00        e                  24
# 2 2012-01-08 09:04:00 2012-01-08 09:31:00        e                  50
# 3 2012-01-09 12:41:00 2012-01-09 12:48:00        e                  26
# 4 2012-01-09 16:59:00 2012-01-09 17:43:00        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91           10/26/11 0:00                             76
# 1         161             1/6/12 0:00                              2
# 2         141           12/31/11 0:00                              8
# 3         101           11/16/11 0:00                            199
# 4         103           11/23/11 0:00                            100
#
#    student_previous_class_logins  duration  a  c  e  g  m
# 0                             27      1620  0  0  1  0  0
# 1                              0      1620  0  0  1  0  0
# 2                              5      1620  0  0  1  0  0
# 3                            104       420  0  0  1  0  0
# 4                             41      2640  0  0  0  0  1

# %%
#Plot data to identify outliers

# import matplotlib.pyplot as plt

# %%
import statsmodels.api as sm

# Resulting R-squared = .413

X_1 = data[['problems_completed','student_id', 'student_previous_logins_total', 'student_previous_class_logins']].values
y_1 = data['duration'].values

X_1 = sm.add_constant(X_1, prepend=True)
results_1 = sm.OLS(y_1, X_1).fit()

# %%
results_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.413
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     8571.
# Date:                Sun, 26 Oct 2014   Prob (F-statistic):               0.00
# Time:                        13:53:34   Log-Likelihood:            -3.9751e+05
# No. Observations:               48758   AIC:                         7.950e+05
# Df Residuals:                   48753   BIC:                         7.951e+05
# Df Model:                           4
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        -62.8523     13.005     -4.833      0.000       -88.343   -37.362
# x1            64.1941      0.352    182.377      0.000        63.504    64.884
# x2             1.1124      0.026     43.475      0.000         1.062     1.163
# x3             0.5987      0.031     19.357      0.000         0.538     0.659
# x4            -1.0556      0.089    -11.849      0.000        -1.230    -0.881
# ==============================================================================
# Omnibus:                    81556.076   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        689259475.944
# Skew:                          10.439   Prob(JB):                         0.00
# Kurtosis:                     585.096   Cond. No.                     1.39e+03
# ==============================================================================
#
# Warnings:
# [1] The condition number is large, 1.39e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# removing variables, but resulting R-squared was less than results_1

# X_2 = data[['student_id', 'student_previous_logins_total', 'student_previous_class_logins']].values
# y_2 = data['duration'].values

# X_2 = sm.add_constant(X_2, prepend=True)
# results_2 = sm.OLS(y_2, X_2).fit()

# results_2.summary()

# %%
# resulting R-squared: 0.012

# X_3 = data[['student_id', 'student_previous_class_logins']].values
# y_3 = data['duration'].values

# X_3 = sm.add_constant(X_3, prepend=True)
# results_3 = sm.OLS(y_3, X_3).fit()

# %%
# results_3.summary()

# %%
# Resulting R-squared: 0.012

# X_4 = data[['student_id', 'student_previous_logins_total']].values
# y_4 = data['duration'].values
 
# X_4 = sm.add_constant(X_4, prepend=True)
# results_4 = sm.OLS(y_4, X_4).fit()

# %%
# results_4.summary()

# %%
X_5 = data[['problems_completed','student_id']].values
y_5 = data['duration'].values
 
X_5 = sm.add_constant(X_5, prepend=True)
results_5 = sm.OLS(y_5, X_5).fit()

results_5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.408
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                 1.680e+04
# Date:                Sun, 26 Oct 2014   Prob (F-statistic):               0.00
# Time:                        14:27:40   Log-Likelihood:            -3.9771e+05
# No. Observations:               48758   AIC:                         7.954e+05
# Df Residuals:                   48755   BIC:                         7.955e+05
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const         88.8436      9.584      9.270      0.000        70.058   107.629
# x1            63.3102      0.351    180.572      0.000        62.623    63.997
# x2             0.8792      0.022     39.846      0.000         0.836     0.922
# ==============================================================================
# Omnibus:                    81367.555   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        677681440.333
# Skew:                          10.389   Prob(JB):                         0.00
# Kurtosis:                     580.184   Cond. No.                         837.
# ==============================================================================
# """

# %%
dummy_data = pd.get_dummies(data['class_id'])

data = data.join(dummy_data).head()

# %%
data.head()
# Out:
#    session_start_time    session_end_time class_id  problems_completed  \
# 0 2012-01-06 16:28:00 2012-01-06 16:55:00        e                  37
# 1 2012-01-07 11:00:00 2012-01-07 11:27:00        e                  24
# 2 2012-01-08 09:04:00 2012-01-08 09:31:00        e                  50
# 3 2012-01-09 12:41:00 2012-01-09 12:48:00        e                  26
# 4 2012-01-09 16:59:00 2012-01-09 17:43:00        m                  37
#
#    student_id student_account_created  student_previous_logins_total  \
# 0          91           10/26/11 0:00                             76
# 1         161             1/6/12 0:00                              2
# 2         141           12/31/11 0:00                              8
# 3         101           11/16/11 0:00                            199
# 4         103           11/23/11 0:00                            100
#
#    student_previous_class_logins  duration  a  c  e  g  m
# 0                             27      1620  0  0  1  0  0
# 1                              0      1620  0  0  1  0  0
# 2                              5      1620  0  0  1  0  0
# 3                            104       420  0  0  1  0  0
# 4                             41      2640  0  0  0  0  1

# %%
X_6 = data[['problems_completed']].values
y_6 = data['duration'].values

X_6 = sm.add_constant(X_6, prepend=True)
results_6 = sm.OLS(y_6, X_6).fit()

results_6.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.389
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                 3.100e+04
# Date:                Sun, 26 Oct 2014   Prob (F-statistic):               0.00
# Time:                        14:31:36   Log-Likelihood:            -3.9849e+05
# No. Observations:               48758   AIC:                         7.970e+05
# Df Residuals:                   48756   BIC:                         7.970e+05
# Df Model:                           1
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const        349.9795      7.106     49.248      0.000       336.051   363.908
# x1            62.6600      0.356    176.070      0.000        61.962    63.358
# ==============================================================================
# Omnibus:                    79746.995   Durbin-Watson:                   1.967
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        598518723.637
# Skew:                           9.960   Prob(JB):                         0.00
# Kurtosis:                     545.411   Cond. No.                         36.6
# ==============================================================================
# """

# %%
X_7 = data[['a','c','e','g','m']].values
y_7 = data['duration'].values
 
X_7 = sm.add_constant(X_7, prepend=True)
results_7 = sm.OLS(y_7, X_7).fit()

results_7.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.928
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     19.36
# Date:                Sun, 26 Oct 2014   Prob (F-statistic):             0.0193
# Time:                        15:06:00   Log-Likelihood:                -37.802
# No. Observations:                   5   AIC:                             79.60
# Df Residuals:                       3   BIC:                             78.82
# Df Model:                           2
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const               0          0        nan        nan             0         0
# x1                  0          0        nan        nan             0         0
# x2          1320.0000    300.000      4.400      0.022       365.266  2274.734
# x3                  0          0        nan        nan             0         0
# x4          2640.0000    600.000      4.400      0.022       730.532  4549.468
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.083
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.390
# Skew:                          -1.291   Prob(JB):                        0.499
# Kurtosis:                       2.917   Cond. No.                          inf
# ==============================================================================
#
# Warnings:
# [1] The smallest eigenvalue is      0. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
